# %% [markdown]
# Configuracion del PATH

# %%
import sys
sys.path.append("../src")

# %% [markdown]
# Ejercicio a ENTREGAR (punto 10)

# %%
import punto10
punto10.kitchen_tournament()
# Out:
# Ronda 1 - Entrada:
# Ganador: Camila (26 pts)
# Tabla de posiciones :
# Cocinero	  Camila  Valentina   Lucía     Mateo    Santiago
# ----------------------------------------------------------------------
# Puntaje 	    26        24        24        22        19
# Rondas ganadas 	    1         0         0         0         0
# Mejor ronda 	    26        24        24        22        19
# Promedio 	   26.0      24.0      24.0      22.0      19.0
# ----------------------------------------------------------------------
#
# Ronda 2 - Plato principal:
# Ganador: Valentina (26 pts)
# Tabla de posiciones :
# Cocinero	Valentina   Mateo     Camila    Lucía    Santiago
# ----------------------------------------------------------------------
# Puntaje 	    50        46        46        46        44
# Rondas ganadas 	    1         0         1         0         0
# Mejor ronda 	    26        24        26        24        25
# Promedio 	   25.0      23.0      23.0      23.0      22.0
# ...

# %% [markdown]
# Ejercicios adicionales (desde el punto 1 hasta el punto 6)

# %%
import punto1
punto1.text_stadistics()

# %%
import punto2
punto2.playlist_duration()

# %%
import punto3
punto3.spoilers_filter()

# %%
import punto4
punto4.email_validation()

# %%
import punto5
punto5.calculate_delivery()

# %%
import punto6
punto6.hashtag_analisys()
