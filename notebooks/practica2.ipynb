# %% [markdown]
# Configuracion del PATH

# %%
import sys
sys.path.append("../src")

# %%
import punto1
punto1.text_stadistics()

# %%
import punto2
punto2.playlist_duration()

# %%
import punto3
punto3.spoilers_filter()

# %%
import punto4
punto4.email_validation()
